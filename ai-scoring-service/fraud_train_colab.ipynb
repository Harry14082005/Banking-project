# %% [markdown]
# # Fraud Detection Multi‑AI Training (Colab)
# Upload this notebook to Google Colab and run cells from top to bottom.
# It will install dependencies, upload your dataset, train the models, and download the `.pkl` files.

# %%
# Install required libraries
# !pip install pandas numpy scikit-learn xgboost

# %% [markdown]
# ## Upload required files
# Upload these files from your computer:
# - fraudTrain.csv
# - fraudTest.csv
# - model_trainer.py
# - feature_engineering.py (if used by trainer)

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ## Train the models
# This runs your existing training script which builds RandomForest, XGBoost and IsolationForest.

# %%
# !python model_trainer.py

# %% [markdown]
# ## Download trained models
# After training finishes, download the `.pkl` models to your computer.

# %%
from google.colab import files
import os

for f in os.listdir():
    if f.endswith('.pkl'):
        files.download(f)
